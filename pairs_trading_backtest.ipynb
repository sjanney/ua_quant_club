# %% [markdown]
# # Pairs backtest (moved)
#
# The maintained notebook is **`alphas/pairs_trading/notebook.ipynb`**. It uses **`data.fetcher`** for cached real data, **`config.yaml`** for parameters, and the improved strategy in **`alphas/pairs_trading/strategy.py`** (rolling hedge ratio, crossing entries, optional Bonferroni / half-life).
#
# Open that file from the repo root and run all cells top to bottom.

# %%
from pathlib import Path
p = Path("alphas/pairs_trading/notebook.ipynb").resolve()
print("Canonical notebook:", p)
print("Exists:", p.is_file())
